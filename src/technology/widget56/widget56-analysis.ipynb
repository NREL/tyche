# %%
import os
import sys
sys.path.insert(0, os.path.abspath("../../../src"))
import numpy             as np
import matplotlib.pyplot as pl
import pandas            as pd
import seaborn           as sb
import tyche             as ty

# %%
designs = ty.Designs(path = ".",
                     name = 'widget56.xlsx')
investments = ty.Investments(path = ".",
                             name = 'widget56.xlsx')
# Out:
# > c:\users\rhanes\github\tyche\src\tyche\io.py(136)check_tables()
#     134     _des_tecsce_var_eq.append(i.to_frame() for i in _des_tecsce_var if not _des_tecsce_var[0].equals(i))
#     135     pdb.set_trace()
# --> 136     if len(_des_tecsce_var_eq) != 0:
#     137       check_list.append(
#     138         ('Data Validation: Some Technology-Scenarios do not have correct '
#
# ipdb> _des_tecsce_var_eq
# [<generator object check_tables.<locals>.<genexpr> at 0x000001BFD264C5C8>]
# ipdb> i
# *** NameError: name 'i' is not defined
# ipdb> _des_tecsce_var
# [Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable'), Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable')]
# ipdb> _des_tecsce_var[0]
# Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#        'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#        'Lifetime', 'Output efficiency', 'Output price', 'Scale'],
#       dtype='object', name='Variable')
# ipdb> _des_tecsce_var[0].to_frame()
#                             Variable
# Variable
# Input                          Input
# Input                          Input
# Input efficiency    Input efficiency
# Input efficiency    Input efficiency
# Input price              Input price
# Input price              Input price
# Lifetime                    Lifetime
# Lifetime                    Lifetime
# Lifetime                    Lifetime
# Lifetime                    Lifetime
# Lifetime                    Lifetime
# Output efficiency  Output efficiency
# Output price            Output price
# Scale                          Scale
# ipdb> _des_tecsce_var[0].to_list()
# ['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price', 'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime', 'Output efficiency', 'Output price', 'Scale']
# ipdb> [i in _des_tecsce_var if not _des_tecsce_var[0].equals(i)]
# *** SyntaxError: invalid syntax
# ...
# ipdb> _des_tecsce_var_eq
# [<generator object check_tables.<locals>.<genexpr> at 0x000001BFD264C5C8>]
# ipdb> _des_tecsce_var_eq.to_frame()
# *** AttributeError: 'list' object has no attribute 'to_frame'
# ipdb> _des_tecsce_var_eq[0].to_frame()
# *** AttributeError: 'generator' object has no attribute 'to_frame'
# ipdb> _des_tecsce_var_eq = [i.to_frame() for i in _des_tecsce_var if not _des_tecsce_var[0].equals(i)]
# *** NameError: name '_des_tecsce_var' is not defined
# ipdb> interact
# *interactive*
# In : _des_tecsce_var_eq = [i.to_frame() for i in _des_tecsce_var if not _des_tecsce_var[0].equals(i)]
# In : _des_tecsce_var_eq
# [                            Variable
#  Variable
#  Input                          Input
#  Input                          Input
#  Input efficiency    Input efficiency
#  Input efficiency    Input efficiency
#  Input price              Input price
#  Input price              Input price
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Output efficiency  Output efficiency
#  Output price            Output price
#  Scale                          Scale,
#                              Variable
#  Variable
#  Input                          Input
#  Input                          Input
#  Input efficiency    Input efficiency
#  Input efficiency    Input efficiency
#  Input price              Input price
#  Input price              Input price
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Output efficiency  Output efficiency
#  Output price            Output price
#  Scale                          Scale,
#                              Variable
#  Variable
#  Input                          Input
#  Input                          Input
#  Input efficiency    Input efficiency
#  Input efficiency    Input efficiency
#  Input price              Input price
#  Input price              Input price
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Output efficiency  Output efficiency
#  Output price            Output price
#  Scale                          Scale,
#                              Variable
#  Variable
#  Input                          Input
#  Input                          Input
#  Input efficiency    Input efficiency
#  Input efficiency    Input efficiency
#  Input price              Input price
#  Input price              Input price
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Output efficiency  Output efficiency
#  Output price            Output price
#  Scale                          Scale,
#                              Variable
#  Variable
#  Input                          Input
#  Input                          Input
#  Input efficiency    Input efficiency
#  Input efficiency    Input efficiency
#  Input price              Input price
#  Input price              Input price
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Output efficiency  Output efficiency
#  Output price            Output price
#  Scale                          Scale,
#                              Variable
#  Variable
#  Input                          Input
#  Input                          Input
#  Input efficiency    Input efficiency
#  Input efficiency    Input efficiency
#  Input price              Input price
#  Input price              Input price
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Output efficiency  Output efficiency
#  Output price            Output price
#  Scale                          Scale,
#                              Variable
#  Variable
#  Input                          Input
#  Input                          Input
#  Input efficiency    Input efficiency
#  Input efficiency    Input efficiency
#  Input price              Input price
#  Input price              Input price
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Output efficiency  Output efficiency
#  Output price            Output price
#  Scale                          Scale,
#                              Variable
#  Variable
#  Input                          Input
#  Input                          Input
#  Input efficiency    Input efficiency
#  Input efficiency    Input efficiency
#  Input price              Input price
#  Input price              Input price
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Output efficiency  Output efficiency
#  Output price            Output price
#  Scale                          Scale,
#                              Variable
#  Variable
#  Input                          Input
#  Input                          Input
#  Input efficiency    Input efficiency
#  Input efficiency    Input efficiency
#  Input price              Input price
#  Input price              Input price
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Output efficiency  Output efficiency
#  Output price            Output price
#  Scale                          Scale,
#                              Variable
#  Variable
#  Input                          Input
#  Input                          Input
#  Input efficiency    Input efficiency
#  Input efficiency    Input efficiency
#  Input price              Input price
#  Input price              Input price
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Output efficiency  Output efficiency
#  Output price            Output price
#  Scale                          Scale,
#                              Variable
#  Variable
#  Input                          Input
#  Input                          Input
#  Input efficiency    Input efficiency
#  Input efficiency    Input efficiency
#  Input price              Input price
#  Input price              Input price
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Output efficiency  Output efficiency
#  Output price            Output price
#  Scale                          Scale,
#                              Variable
#  Variable
#  Input                          Input
#  Input                          Input
#  Input efficiency    Input efficiency
#  Input efficiency    Input efficiency
#  Input price              Input price
#  Input price              Input price
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Output efficiency  Output efficiency
#  Output price            Output price
#  Scale                          Scale,
#                              Variable
#  Variable
#  Input                          Input
#  Input                          Input
#  Input efficiency    Input efficiency
#  Input efficiency    Input efficiency
#  Input price              Input price
#  Input price              Input price
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Lifetime                    Lifetime
#  Output efficiency  Output efficiency
#  Output price            Output price
#  Scale                          Scale]
# In : [i for i in _des_tecsce_var if not _des_tecsce_var[0].equals(i)]
# [Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#         'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#         'Output efficiency', 'Output price', 'Scale'],
#        dtype='object', name='Variable'),
#  Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#         'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#         'Output efficiency', 'Output price', 'Scale'],
#        dtype='object', name='Variable'),
#  Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#         'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#         'Output efficiency', 'Output price', 'Scale'],
#        dtype='object', name='Variable'),
#  Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#         'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#         'Output efficiency', 'Output price', 'Scale'],
#        dtype='object', name='Variable'),
#  Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#         'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#         'Output efficiency', 'Output price', 'Scale'],
#        dtype='object', name='Variable'),
#  Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#         'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#         'Output efficiency', 'Output price', 'Scale'],
#        dtype='object', name='Variable'),
#  Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#         'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#         'Output efficiency', 'Output price', 'Scale'],
#        dtype='object', name='Variable'),
#  Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#         'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#         'Output efficiency', 'Output price', 'Scale'],
#        dtype='object', name='Variable'),
#  Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#         'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#         'Output efficiency', 'Output price', 'Scale'],
#        dtype='object', name='Variable'),
#  Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#         'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#         'Output efficiency', 'Output price', 'Scale'],
#        dtype='object', name='Variable'),
#  Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#         'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#         'Output efficiency', 'Output price', 'Scale'],
#        dtype='object', name='Variable'),
#  Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#         'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#         'Output efficiency', 'Output price', 'Scale'],
#        dtype='object', name='Variable'),
#  Index(['Input', 'Input', 'Input efficiency', 'Input efficiency', 'Input price',
#         'Input price', 'Lifetime', 'Lifetime', 'Lifetime', 'Lifetime',
#         'Output efficiency', 'Output price', 'Scale'],
#        dtype='object', name='Variable')]
# In : _des_tecsce_var = [designs.loc[i[:2],2].index for i in designs.index.values]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\tyche\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Local\Continuum\anaconda3\envs\tyche\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Continuum\anaconda3\envs\tyche\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\tyche\lib\code.py in runcode(self, code)
#      88         """
#      89         try:
# ---> 90             exec(code, self.locals)
#      91         except SystemExit:
#      92             raise
#
# ~\GitHub\tyche\src\tyche\IO.py in <module>
#
# ~\GitHub\tyche\src\tyche\IO.py in <listcomp>(.0)
#
# ~\AppData\Local\Continuum\anaconda3\envs\tyche\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~\AppData\Local\Continuum\anaconda3\envs\tyche\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1098     def _getitem_tuple(self, tup: tuple):
#    1099         with suppress(IndexingError):
# -> 1100             return self._getitem_lowerdim(tup)
#    1101
#    1102         # no multi-index, so validate all of the indexers
#
# ~\AppData\Local\Continuum\anaconda3\envs\tyche\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     820         # we may have a nested tuples indexer here
#     821         if self._is_nested_tuple_indexer(tup):
# --> 822             return self._getitem_nested_tuple(tup)
#     823
#     824         # we maybe be using a tuple to represent multiple dimensions here
#
# ~\AppData\Local\Continuum\anaconda3\envs\tyche\lib\site-packages\pandas\core\indexing.py in _getitem_nested_tuple(self, tup)
#     904                 continue
#     905
# --> 906             obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#     907             axis -= 1
#     908
#
# ~\AppData\Local\Continuum\anaconda3\envs\tyche\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\AppData\Local\Continuum\anaconda3\envs\tyche\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1111     def _get_label(self, label, axis: int):
#    1112         # GH#5667 this will fail if the label is not present in the axis.
# -> 1113         return self.obj.xs(label, axis=axis)
#    1114
#    1115     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# ~\AppData\Local\Continuum\anaconda3\envs\tyche\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3759         if axis == 1:
#    3760             if drop_level:
# -> 3761                 return self[key]
#    3762             index = self.columns
#    3763         else:
#
# ~\AppData\Local\Continuum\anaconda3\envs\tyche\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\AppData\Local\Continuum\anaconda3\envs\tyche\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 2

# %%
designs.compile()

# %%
investments.compile()
