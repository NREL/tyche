# %% [markdown]
# # Tyche Example - Biorefinery Toy Model

# %% [markdown]
# ## Set up.

# %% [markdown]
# ### One only needs to execute the following line once, in order to make sure recent enough packages are installed.

# %%
# !pip install 'numpy>=1.17.2' 'pandas>=0.25.1'

# %% [markdown]
# ### Import packages.

# %%
import numpy             as np
import matplotlib.pyplot as pl
import pandas            as pd
import re                as re

# The `tyche` package is located at <https://github.com/NREL/portfolio/tree/master/production-function/framework/code/tyche/>.
import tyche             as ty

# %% [markdown]
# ## Load data.

# %% [markdown]
# ### The data are stored in a set of tab-separated value files in a folder.

# %%
scenarios = ty.Designs("../data-biorefinery")

# %% [markdown]
# ### Compile the production and metric functions for each technology in the dataset.

# %%
scenarios.compile()

# %% [markdown]
# ## Examine the data.

# %% [markdown]
# ### The `functions` table specifies where the Python code for each technology resides.

# %%
scenarios.functions
# Out:
#                   Module  Production  Metrics Notes
# Technology
# Biorefinery  biorefinery  production  metrics

# %% [markdown]
# ### The `indices` table defines the subscripts for variables.

# %%
scenarios.indices
# Out:
#                                                Offset Description Notes
# Technology  Type                Index
# Biorefinery Capital             Conversion          2
#                                 Fermentation        1
#                                 Preprocessing       0
#                                 Separation          3
#             Fixed               Insurance           1
#                                 Rent                0
#             Input               Energy              1
#                                 Feedstock           0
#             Metric              Jobs                0
#             Output              Product             0
#             Technical Parameter Conversion          1
#                                 Fermentation        0

# %% [markdown]
# ### The `designs` table contains the cost, input, efficiency, and price data for a scenario.

# %%
scenarios.designs
# Out:
#                                                         Value  \
# Technology  Scenario Variable          Index
# Biorefinery Actual   Capital cost      Conversion      750.00
#                                        Fermentation   1500.00
#                                        Preprocessing  1000.00
#                                        Separation     1250.00
#                      Fixed cost        Insurance      2000.00
#                                        Rent           5000.00
#                      Input             Energy         5000.00
#                                        Feedstock      3000.00
#                      Input efficiency  Energy            0.71
#                                        Feedstock         0.82
#                      Input price       Energy            0.50
#                                        Feedstock        45.00
#                      Lifetime          Conversion       25.00
#                                        Fermentation     25.00
#                                        Preprocessing    25.00
#                                        Separation       25.00
#                      Output efficiency Product           0.80
#                      Output price      Product         600.00
#                      Scale             NaN               1.00
#             Ideal    Capital cost      Conversion      750.00
#                                        Fermentation   1500.00
#                                        Preprocessing  1000.00
#                                        Separation     1250.00
#                      Fixed cost        Insurance      2000.00
#                                        Rent           5000.00
#                      Input             Energy         5000.00
#                                        Feedstock      3000.00
#                      Input efficiency  Energy            0.85
#                                        Feedstock         0.90
#                      Input price       Energy            0.50
#                                        Feedstock        45.00
#                      Lifetime          Conversion       25.00
#                                        Fermentation     25.00
#                                        Preprocessing    25.00
#                                        Separation       25.00
#                      Output efficiency Product           0.89
#                      Output price      Product         600.00
#                      Scale             NaN               1.00
#
#                                                                            Units  \
# Technology  Scenario Variable          Index
# Biorefinery Actual   Capital cost      Conversion                            USD
#                                        Fermentation                          USD
#                                        Preprocessing                         USD
#                                        Separation                            USD
#                      Fixed cost        Insurance                        USD/year
#                                        Rent                             USD/year
#                      Input             Energy                     MJ/biorefinery
#                                        Feedstock      tons feedstock/biorefinery
#                      Input efficiency  Energy                                  1
#                                        Feedstock                               1
#                      Input price       Energy                             USD/MJ
#                                        Feedstock               USD/ton feedstock
#                      Lifetime          Conversion                           year
#                                        Fermentation                         year
#                                        Preprocessing                        year
#                                        Separation                           year
#                      Output efficiency Product                                 1
#                      Output price      Product                   USD/ton product
#                      Scale             NaN                      biorefinery/year
#             Ideal    Capital cost      Conversion                            USD
#                                        Fermentation                          USD
#                                        Preprocessing                         USD
#                                        Separation                            USD
#                      Fixed cost        Insurance                        USD/year
#                                        Rent                             USD/year
#                      Input             Energy                     MJ/biorefinery
#                                        Feedstock      tons feedstock/biorefinery
#                      Input efficiency  Energy                                  1
#                                        Feedstock                               1
#                      Input price       Energy                             USD/MJ
#                                        Feedstock               USD/ton feedstock
#                      Lifetime          Conversion                           year
#                                        Fermentation                         year
#                                        Preprocessing                        year
#                                        Separation                           year
#                      Output efficiency Product                                 1
#                      Output price      Product                   USD/ton product
#                      Scale             NaN                      biorefinery/year
#
#                                                      Notes
# Technology  Scenario Variable          Index
# Biorefinery Actual   Capital cost      Conversion
#                                        Fermentation
#                                        Preprocessing
#                                        Separation
#                      Fixed cost        Insurance
#                                        Rent
#                      Input             Energy
#                                        Feedstock
#                      Input efficiency  Energy
#                                        Feedstock
#                      Input price       Energy
#                                        Feedstock
#                      Lifetime          Conversion
#                                        Fermentation
#                                        Preprocessing
#                                        Separation
#                      Output efficiency Product
#                      Output price      Product
#                      Scale             NaN
#             Ideal    Capital cost      Conversion
#                                        Fermentation
#                                        Preprocessing
#                                        Separation
#                      Fixed cost        Insurance
#                                        Rent
#                      Input             Energy
#                                        Feedstock
#                      Input efficiency  Energy
#                                        Feedstock
#                      Input price       Energy
#                                        Feedstock
#                      Lifetime          Conversion
#                                        Fermentation
#                                        Preprocessing
#                                        Separation
#                      Output efficiency Product
#                      Output price      Product
#                      Scale             NaN

# %% [markdown]
# ### The `parameters` table contains additional techno-economic parameters for each technology.

# %%
scenarios.parameters
# Out:
#                                          Offset  Value Units Notes
# Technology  Scenario Parameter
# Biorefinery Actual   Conversion yield         1   0.81
#                      Fermentation yield       0   0.70
#                      Jobs                     2   2.00
#             Ideal    Conversion yield         1   0.95
#                      Fermentation yield       0   0.82
#                      Jobs                     2   4.00

# %% [markdown]
# ### The `results` table specifies the units of measure for results of computations.

# %%
scenarios.results
# Out:
#                                                  Units Notes
# Technology  Variable Index
# Biorefinery Cost     Cost              USD/biorefinery
#             Metric   Jobs             jobs/biorefinery
#             Output   Product  tons product/biorefinery

# %% [markdown]
# ## Evaluate the designs in the dataset.

# %%
results = scenarios.evaluate_all()

# %%
results
# Out:
#                                             Value                     Units
# Technology  Scenario Variable Index
# Biorefinery Actual   Cost     Cost    -549858.600           USD/biorefinery
#                      Metric   Jobs          2.000          jobs/biorefinery
#                      Output   Product    1115.856  tons product/biorefinery
#             Ideal    Cost     Cost    -992357.200           USD/biorefinery
#                      Metric   Jobs          4.000          jobs/biorefinery
#                      Output   Product    1871.937  tons product/biorefinery
