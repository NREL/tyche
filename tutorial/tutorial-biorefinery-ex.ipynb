# %% [markdown]
# # Tutorial

# %% [markdown]
# ## Prerequisites.

# %% [markdown]
# #### Download and install Miniconda, Anaconda, or Conda.

# %% [markdown]
# https://docs.conda.io/en/latest/miniconda.html

# %% [markdown]
# ### Create the Conda environment.

# %% [markdown]
# ```
# conda env create --file conda\win.yml
# conda activate tyche
# pip install mip
# ```

# %% [markdown]
# #### Activate the Tyche environment.

# %% [markdown]
# ```
# conda activate tyche
# ```

# %% [markdown]
# ## Set up.

# %% [markdown]
# ### Import packages.

# %% [markdown]
# #### Import the system packages.

# %%
import os
import sys

# %% [markdown]
# #### Add the main Tyche packages to the search path.

# %%
sys.path.insert(1, os.path.abspath("../src"))

# %% [markdown]
# #### Import tyche and related packages.

# %%
import numpy             as np
import matplotlib.pyplot as pl
import pandas            as pd
import seaborn           as sb
import tyche             as ty

# %% [markdown]
# ## Design the technology model.

# %% [markdown]
# ### Technology name.

# %% [markdown]
# Choose a unique name for the technology being modeled: **Biorefinery 1.0**
#
# Also choose a unique name for the default, reference, or base-case scenario: **Bioreference**

# %% [markdown]
# ### Dimensions and indices.

# %% [markdown]
# Decide which quantities will be tracked as indices in the model, and settle on their units of measurment and default values:
# 1.  Types of capital costs: **preprocessing, fermentation, conversion, separations, utilities** Units: USD/biorefinery
# 2.  Types of fixed cost: **rent, insurance** Units: USD/year
# 3.  Inputs to the process: **feedstock** (metric tons/year), **natural gas** (MJ/year)
# 4.  Outputs from the process: **biofuel** (gal/year)
# 5.  Metrics: **fossil GHG** (kg CO2-eq/gal biofuel), **total GHG** (kg CO2-eq/gal biofuel), **jobs** (person-hours/gal biofuel)
# 6.  Parameters:  **fossil GHG** (kg CO2-eq/year), **biogenic GHG** (kg CO2-eq/year), **employment** (person-hours/year), **preprocessing capital cost** (USD/biorefinery), **fermentation capital cost** (USD/biorefinery), **conversion capital cost** (USD/biorefinery), **separations capital cost** (USD/biorefinery), **utilities capital cost** (USD/biorefinery)
#
# Note that in each category, the numeric indices for each item are numbered with integers starting from zero.
#
# See the [model](https://tyche.live/doc-src/formulation.html) and [database](https://tyche.live/doc-src/database.html) documentation for more details.

# %% [markdown]
# ### Create the `indices` table.

# %% [markdown]
# Check to see that the data file reads correctly:

# %%
my_designs = ty.Designs("data/biorefinery_v1/")
my_designs.indices.reset_index("Index").sort_values(["Type", "Offset"])
# Out:
#                                                          Index  Offset  \
# Technology     Type
# Biorefinery v1 Capital                           Preprocessing       0
#                Capital                            Fermentation       1
#                Capital                              Conversion       2
#                Capital                             Separations       3
#                Capital                               Utilities       4
#                Fixed                                      Rent       0
#                Fixed                                 Insurance       1
#                Input                                 Feedstock       0
#                Input                               Natural Gas       1
#                Metric                                     Jobs       0
#                Metric                               Fossil GHG       1
#                Metric                                Total GHG       2
#                Output                                  Biofuel       0
#                Technical Parameter                  Fossil GHG       0
#                Technical Parameter                Biogenic GHG       1
#                Technical Parameter                  Employment       2
#                Technical Parameter  Preprocessing Capital Cost       3
#                Technical Parameter   Fermentation Capital Cost       4
#                Technical Parameter     Conversion Capital Cost       5
#                Technical Parameter    Separations Capital Cost       6
#                Technical Parameter      Utilities Capital Cost       7
#                Technical Parameter                        Rent       8
#                Technical Parameter                   Insurance       9
#                Technical Parameter              Original Scale      10
#                Technical Parameter              Scaling Factor      11
#                Technical Parameter         Ideal Biofuel Yield      12
#
#                                                    Description Notes
# Technology     Type
# Biorefinery v1 Capital              process area capital costs
#                Capital              process area capital costs
#                Capital              process area capital costs
#                Capital              process area capital costs
#                Capital              process area capital costs
#                Fixed
#                Fixed
#                Input
#                Input
#                Metric                 person-hours/gal biofuel
#                Metric                    kg CO2-eq/gal biofuel
#                Metric                    kg CO2-eq/gal biofuel
#                Output
#                Technical Parameter              kg CO2-eq/year
#                Technical Parameter              kg CO2-eq/year
#                Technical Parameter           person-hours/year
#                Technical Parameter             USD/biorefinery
#                Technical Parameter             USD/biorefinery
#                Technical Parameter             USD/biorefinery
#                Technical Parameter             USD/biorefinery
#                Technical Parameter             USD/biorefinery
#                Technical Parameter                    USD/year
#                Technical Parameter                    USD/year
#                Technical Parameter                    unitless
#                Technical Parameter                    unitless
#                Technical Parameter              gal/metric ton

# %% [markdown]
# ### Create the `results` table.

# %% [markdown]
# Check to see that the data file reads correctly:

# %%
my_designs.results
# Out:
#                                                        Units  \
# Technology     Variable Index
# Biorefinery v1 Cost     Cost                        USD/year
#                Metric   Fossil GHG     kg CO2-eq/gal biofuel
#                         Jobs        person-hours/gal biofuel
#                         Total GHG      kg CO2-eq/gal biofuel
#                Output   Biofuel                     gal/year
#
#                                                                          Notes
# Technology     Variable Index
# Biorefinery v1 Cost     Cost
#                Metric   Fossil GHG
#                         Jobs
#                         Total GHG
#                Output   Biofuel     average over expected biorefinery lifetime

# %% [markdown]
# ### Create the `designs` table.

# %% [markdown]
# Check to see that the data file reads correctly:

# %%
my_designs.designs.reset_index(["Variable", "Index"]).sort_values(["Variable", "Index"])
# Out:
#                                Variable        Index   Value            Units  \
# Technology     Scenario
# Biorefinery v1 Bioreference       Input    Feedstock  771750  metric ton/year
#                Conversion 0       Input    Feedstock  771750  metric ton/year
#                Conversion 1       Input    Feedstock  771750  metric ton/year
#                Conversion 2       Input    Feedstock  771750  metric ton/year
#                Fermentation 0     Input    Feedstock  771750  metric ton/year
# ...                                 ...          ...     ...              ...
#                Preprocessing 1    Scale  Biorefinery       1         unitless
#                Preprocessing 2    Scale  Biorefinery       1         unitless
#                Separations 0      Scale  Biorefinery       1         unitless
#                Separations 1      Scale  Biorefinery       1         unitless
#                Separations 2      Scale  Biorefinery       1         unitless
#
#                                                               Notes
# Technology     Scenario
# Biorefinery v1 Bioreference     per one year of expected operations
#                Conversion 0     per one year of expected operations
#                Conversion 1     per one year of expected operations
#                Conversion 2     per one year of expected operations
#                Fermentation 0   per one year of expected operations
# ...                                                             ...
#                Preprocessing 1
#                Preprocessing 2
#                Separations 0
#                Separations 1
#                Separations 2
#
# [182 rows x 5 columns]

# %% [markdown]
# ### Create the `parameters` table.

# %% [markdown]
# Check to see that the data file reads correctly:

# %%
my_designs.parameters.reset_index("Parameter").sort_values("Scenario")
# Out:
#                                                Parameter  Offset      Value  \
# Technology     Scenario
# Biorefinery v1 Bioreference                 Biogenic GHG       1  115762500
#                Bioreference       Utilities Capital Cost       7    1250000
#                Bioreference     Separations Capital Cost       6   50000000
#                Bioreference               Scaling Factor      11        0.6
#                Bioreference   Preprocessing Capital Cost       3    1500000
# ...                                                  ...     ...        ...
#                Separations 2     Conversion Capital Cost       5  100000000
#                Separations 2                Biogenic GHG       1  115762500
#                Separations 2    Separations Capital Cost       6   45750000
#                Separations 2         Ideal Biofuel Yield      12     103.95
#                Separations 2      Utilities Capital Cost       7    1250000
#
#                                         Units Notes
# Technology     Scenario
# Biorefinery v1 Bioreference    kg CO2-eq/year
#                Bioreference   USD/biorefinery
#                Bioreference   USD/biorefinery
#                Bioreference          unitless
#                Bioreference   USD/biorefinery
# ...                                       ...   ...
#                Separations 2  USD/biorefinery
#                Separations 2   kg CO2-eq/year
#                Separations 2  USD/biorefinery
#                Separations 2   gal/metric ton
#                Separations 2  USD/biorefinery
#
# [169 rows x 5 columns]

# %% [markdown]
# ## Implement the technology model.

# %% [markdown]
# The implementation of a technology model consists of a capital cost function, a fixed cost function, a production function, and a metrics function.
#
# See the [model](https://tyche.live/doc-src/formulation.html) documentation for more details.

# %% [markdown]
# The [src/technology/](../src/technology/) folder has examples of several technology models.

# %% [markdown]
# #### Capital cost function.

# %% [markdown]
# The capital cost function takes the scale of the operations and the array of technology parameters as arguments and it returns the capital costs for the technology.

# %%
def capital_cost(scale, parameter):
    """
    Capital cost function.

    Parameters
    ----------
    scale : float
      The scale of operation.
    parameter : array
      The technological parameterization.

    Returns
    -------
    @TODO update docstring
    Total capital cost for one biorefinery (USD/biorefinery)
    """
    # "original" biorefinery scale
    o_scale = parameter[10]

    # scaling factor for equipment costs
    scale_factor = parameter[11]

    pre = parameter[3] * (scale / o_scale) ** scale_factor
    fer = parameter[4] * (scale / o_scale) ** scale_factor
    con = parameter[5] * (scale / o_scale) ** scale_factor
    sep = parameter[6] * (scale / o_scale) ** scale_factor
    utl = parameter[7] * (scale / o_scale) ** scale_factor

    return np.stack([pre, fer, con, sep, utl])

# %% [markdown]
# Implement the capital cost function for your technology in the file [tutorial/my_technology.py](./).

# %% [markdown]
# #### Fixed cost function.

# %% [markdown]
# The fixed cost function takes the scale of the operations and the array of technology parameters as arguments and it returns the fixed costs for the technology.

# %%
def fixed_cost(scale, parameter):
    """
    Fixed cost function.

    Parameters
    ----------
    scale : float [Unused]
      The scale of operation.
    parameter : array
      The technological parameterization.

    Returns
    -------
    total fixed costs for one biorefinery (USD/year)
    """
    o_scale = parameter[10]

    rnt = parameter[8] * (scale / o_scale)
    ins = parameter[9] * (scale / o_scale)

    return np.stack([rnt, ins])

# %% [markdown]
# Implement the fixed cost function for your technology in the file [tutorial/my_technology.py](./).

# %% [markdown]
# #### Production function.

# %% [markdown]
# The production function takes the scale of the operations, the capital costs, the lifetime, the fixed costs, and the array of technology parameters as arguments and it returns the production (outputs) for the technology.

# %%
def production(scale, capital, lifetime, fixed, input, parameter):
    """
    Production function.

    Parameters
    ----------
    scale : float
      The scale of operation.
    capital : array
      Capital costs.
    lifetime : float
      Technology lifetime.
    fixed : array
      Fixed costs.
    input : array
      Input quantities.
    parameter : array
      The technological parameterization.

    Returns
    -------
    output_raw
        Ideal/theoretical production of each technology output: biofuel at
        gals/year
    """

    theor_yield = parameter[12]
    feedstock = input[0] * scale

    # theoretical biofuel yield w/out any efficiency losses
    output_raw = theor_yield * feedstock

    return np.stack([output_raw])

# %% [markdown]
# Implement the production function for your technology in the file [tutorial/my_technology.py](./).

# %% [markdown]
# #### Metric function.

# %% [markdown]
# The metric function takes information on costs, inputs, outputs, and parameters and it returns the metrics for the technology.

# %%
def metrics(scale, capital, lifetime, fixed, input_raw, input, output_raw, output, cost, parameter):
    """
    Metrics function.

    Parameters
    ----------
    scale : float
      The scale of operation. Unitless
    capital : array
      Capital costs. Units: USD/biorefinery
    lifetime : float
      Technology lifetime. Units: year
    fixed : array
      Fixed costs. Units: USD/year
    input_raw : array
      Raw input quantities (before losses). Units: metric ton feedstock/year
    input : array
      Input quantities. Units: metric ton feedstock/year
    output_raw : array
      Raw output quantities (before losses). Units: gal biofuel/year
    output : array
      Output quantities including losses. Units: gal biofuel/year
    cost : array
      Annual cost of biorefinery operation. Units: USD/year
    parameter : array
      The technological parameterization. Units vary; given in comments below
    """

    # JOBS: person-hours/gal biofuel
    # parameter[2] units: person-hours/year
    # output units: gal biofuel/year
    emp = parameter[2] / output

    # FOSSIL GHG: kg CO2-eq/gal biofuel
    # parameter[0] units: kg CO2-eq/year
    # output units: gal biofuel/year
    ghg_foss = parameter[0] / output

    # TOTAL GHG: kg CO2-eq/gal biofuel
    # parameter[0] and parameter[1] units: kg CO2-eq/year
    # output units: gal biofuel/year
    ghg_tot = (parameter[0] + parameter[1]) / output

    return np.stack([emp, ghg_foss, ghg_tot])

# %% [markdown]
# Implement the metrics function for your technology in the file [tutorial/my_technology.py](./).

# %% [markdown]
# ### Create the `functions` table.

# %% [markdown]
# Check to see that the data file reads correctly:

# %%
my_designs.functions
# Out:
#                 Style          Module       Capital       Fixed  Production  \
# Technology
# Biorefinery v1  numpy  biorefinery_v1  capital_cost  fixed_cost  production
#
#                 Metrics Notes
# Technology
# Biorefinery v1  metrics

# %% [markdown]
# Check to see that the functions compile without errors.

# %%
my_designs.compile()

# %% [markdown]
# ## Create investment for reference case.

# %% [markdown]
# ### Create the `tranches` table.

# %% [markdown]
# Check to see that the data file reads correctly:

# %%
my_investments = ty.Investments("data/biorefinery_v1")
my_investments.tranches
# Out:
#                                                           Amount Notes
# Category      Tranche                 Scenario
# Conversion    Conversion 0            Conversion 0      800000.0
#               Conversion 1            Conversion 1     2000000.0
#               Conversion 2            Conversion 2     2250000.0
#               Conversion Reference    Bioreference           0.0
# Fermentation  Fermentation 0          Fermentation 0    250000.0
#               Fermentation 1          Fermentation 1    400000.0
#               Fermentation 2          Fermentation 2    500000.0
#               Fermentation Reference  Bioreference           0.0
# Preprocessing Preprocessing 0         Preprocessing 0   500000.0
#               Preprocessing 1         Preprocessing 1  1500000.0
#               Preprocessing 2         Preprocessing 2  1750000.0
#               Preprocessing Reference Bioreference           0.0
# Separations   Separations 0           Separations 0     500000.0
#               Separations 1           Separations 1    2000000.0
#               Separations 2           Separations 2    4000000.0
#               Separations Reference   Bioreference           0.0

# %% [markdown]
# ### Create the `investments` table.

# %% [markdown]
# Check to see that the data file reads correctly:

# %%
my_investments = ty.Investments("data/biorefinery_v1")
my_investments.investments
# Out:
#                                                    Notes
# Investment   Category      Tranche
# High R&D     Conversion    Conversion 2
#              Fermentation  Fermentation 2
#              Preprocessing Preprocessing 2
#              Separations   Separations 2
# Low R&D      Conversion    Conversion 0
#              Fermentation  Fermentation 0
#              Preprocessing Preprocessing 0
#              Separations   Separations 0
# Moderate R&D Conversion    Conversion 1
#              Fermentation  Fermentation 1
#              Preprocessing Preprocessing 1
#              Separations   Separations 1
# No R&D       Conversion    Conversion Reference
#              Fermentation  Fermentation Reference
#              Preprocessing Preprocessing Reference
#              Separations   Separations Reference

# %% [markdown]
# ## Simulate the base case or reference scenario.

# %% [markdown]
# ### Load the data.

# %%
my_designs = ty.Designs("data/biorefinery_v1")

# %%
my_investments = ty.Investments("data/biorefinery_v1")

# %% [markdown]
# ### Compile the production and metric functions for each technology in the dataset.

# %%
my_designs.compile()

# %% [markdown]
# ### Compute costs and metrics for tranches.

# %% [markdown]
# Tranches are atomic units for building investment portfolios. Evaluate all of the tranches, so we can assemble them into investments (portfolios).

# %%
tranche_results = my_investments.evaluate_tranches(my_designs, sample_count=1)

# %% [markdown]
# The tranche amounts are simple how much each tranche costs.

# %%
tranche_results.amounts
# Out:
#                                           Amount
# Category      Tranche
# Conversion    Conversion 0              800000.0
#               Conversion 1             2000000.0
#               Conversion 2             2250000.0
#               Conversion Reference           0.0
# Fermentation  Fermentation 0            250000.0
#               Fermentation 1            400000.0
#               Fermentation 2            500000.0
#               Fermentation Reference         0.0
# Preprocessing Preprocessing 0           500000.0
#               Preprocessing 1          1500000.0
#               Preprocessing 2          1750000.0
#               Preprocessing Reference        0.0
# Separations   Separations 0             500000.0
#               Separations 1            2000000.0
#               Separations 2            4000000.0
#               Separations Reference          0.0

# %% [markdown]
# The tranch metrics show the values of each metric for each member of the ensemble of simulations.

# %%
tranche_results.metrics
# Out:
#                                                                                            Value  \
# Category      Tranche                 Scenario        Sample Technology     Index
# Conversion    Conversion Reference    Bioreference    1      Biorefinery v1 Fossil GHG  3.322701
#                                                                             Jobs        0.002067
#                                                                             Total GHG   5.696058
# Fermentation  Fermentation Reference  Bioreference    1      Biorefinery v1 Fossil GHG  3.322701
#                                                                             Jobs        0.002067
#                                                                             Total GHG   5.696058
# Preprocessing Preprocessing Reference Bioreference    1      Biorefinery v1 Fossil GHG  3.322701
#                                                                             Jobs        0.002067
#                                                                             Total GHG   5.696058
# Separations   Separations Reference   Bioreference    1      Biorefinery v1 Fossil GHG  3.322701
#                                                                             Jobs        0.002067
#                                                                             Total GHG   5.696058
# Conversion    Conversion 0            Conversion 0    1      Biorefinery v1 Fossil GHG  1.863189
#                                                                             Jobs        0.001182
#                                                                             Total GHG   3.221198
#               Conversion 1            Conversion 1    1      Biorefinery v1 Fossil GHG  2.562885
#                                                                             Jobs        0.001753
#                                                                             Total GHG   4.421017
#               Conversion 2            Conversion 2    1      Biorefinery v1 Fossil GHG  2.066160
#                                                                             Jobs        0.001619
#                                                                             Total GHG   3.553890
# Fermentation  Fermentation 0          Fermentation 0  1      Biorefinery v1 Fossil GHG  2.292766
#                                                                             Jobs        0.001448
#                                                                             Total GHG   3.955395
#               Fermentation 1          Fermentation 1  1      Biorefinery v1 Fossil GHG  1.941209
#                                                                             Jobs        0.001392
#                                                                             Total GHG   3.311345
#               Fermentation 2          Fermentation 2  1      Biorefinery v1 Fossil GHG  1.711294
#                                                                             Jobs        0.001311
#                                                                             Total GHG   2.915583
# Preprocessing Preprocessing 0         Preprocessing 0 1      Biorefinery v1 Fossil GHG  1.520443
#                                                                             Jobs        0.001153
#                                                                             Total GHG   2.579984
#               Preprocessing 1         Preprocessing 1 1      Biorefinery v1 Fossil GHG  1.504656
#                                                                             Jobs        0.001039
#                                                                             Total GHG   2.527258
#               Preprocessing 2         Preprocessing 2 1      Biorefinery v1 Fossil GHG  1.535341
#                                                                             Jobs        0.000965
#                                                                             Total GHG   2.558357
# Separations   Separations 0           Separations 0   1      Biorefinery v1 Fossil GHG  2.693340
#                                                                             Jobs        0.001457
#                                                                             Total GHG   4.366222
#               Separations 1           Separations 1   1      Biorefinery v1 Fossil GHG  2.377103
#                                                                             Jobs        0.001554
#                                                                             Total GHG   3.906770
#               Separations 2           Separations 2   1      Biorefinery v1 Fossil GHG  1.932764
#                                                                             Jobs        0.001592
#                                                                             Total GHG   3.303712
#
#                                                                                                            Units
# Category      Tranche                 Scenario        Sample Technology     Index
# Conversion    Conversion Reference    Bioreference    1      Biorefinery v1 Fossil GHG     kg CO2-eq/gal biofuel
#                                                                             Jobs        person-hours/gal biofuel
#                                                                             Total GHG      kg CO2-eq/gal biofuel
# Fermentation  Fermentation Reference  Bioreference    1      Biorefinery v1 Fossil GHG     kg CO2-eq/gal biofuel
#                                                                             Jobs        person-hours/gal biofuel
#                                                                             Total GHG      kg CO2-eq/gal biofuel
# Preprocessing Preprocessing Reference Bioreference    1      Biorefinery v1 Fossil GHG     kg CO2-eq/gal biofuel
#                                                                             Jobs        person-hours/gal biofuel
#                                                                             Total GHG      kg CO2-eq/gal biofuel
# Separations   Separations Reference   Bioreference    1      Biorefinery v1 Fossil GHG     kg CO2-eq/gal biofuel
#                                                                             Jobs        person-hours/gal biofuel
#                                                                             Total GHG      kg CO2-eq/gal biofuel
# Conversion    Conversion 0            Conversion 0    1      Biorefinery v1 Fossil GHG     kg CO2-eq/gal biofuel
#                                                                             Jobs        person-hours/gal biofuel
#                                                                             Total GHG      kg CO2-eq/gal biofuel
#               Conversion 1            Conversion 1    1      Biorefinery v1 Fossil GHG     kg CO2-eq/gal biofuel
#                                                                             Jobs        person-hours/gal biofuel
#                                                                             Total GHG      kg CO2-eq/gal biofuel
#               Conversion 2            Conversion 2    1      Biorefinery v1 Fossil GHG     kg CO2-eq/gal biofuel
#                                                                             Jobs        person-hours/gal biofuel
#                                                                             Total GHG      kg CO2-eq/gal biofuel
# Fermentation  Fermentation 0          Fermentation 0  1      Biorefinery v1 Fossil GHG     kg CO2-eq/gal biofuel
#                                                                             Jobs        person-hours/gal biofuel
#                                                                             Total GHG      kg CO2-eq/gal biofuel
#               Fermentation 1          Fermentation 1  1      Biorefinery v1 Fossil GHG     kg CO2-eq/gal biofuel
#                                                                             Jobs        person-hours/gal biofuel
#                                                                             Total GHG      kg CO2-eq/gal biofuel
#               Fermentation 2          Fermentation 2  1      Biorefinery v1 Fossil GHG     kg CO2-eq/gal biofuel
#                                                                             Jobs        person-hours/gal biofuel
#                                                                             Total GHG      kg CO2-eq/gal biofuel
# Preprocessing Preprocessing 0         Preprocessing 0 1      Biorefinery v1 Fossil GHG     kg CO2-eq/gal biofuel
#                                                                             Jobs        person-hours/gal biofuel
#                                                                             Total GHG      kg CO2-eq/gal biofuel
#               Preprocessing 1         Preprocessing 1 1      Biorefinery v1 Fossil GHG     kg CO2-eq/gal biofuel
#                                                                             Jobs        person-hours/gal biofuel
#                                                                             Total GHG      kg CO2-eq/gal biofuel
#               Preprocessing 2         Preprocessing 2 1      Biorefinery v1 Fossil GHG     kg CO2-eq/gal biofuel
#                                                                             Jobs        person-hours/gal biofuel
#                                                                             Total GHG      kg CO2-eq/gal biofuel
# Separations   Separations 0           Separations 0   1      Biorefinery v1 Fossil GHG     kg CO2-eq/gal biofuel
#                                                                             Jobs        person-hours/gal biofuel
#                                                                             Total GHG      kg CO2-eq/gal biofuel
#               Separations 1           Separations 1   1      Biorefinery v1 Fossil GHG     kg CO2-eq/gal biofuel
#                                                                             Jobs        person-hours/gal biofuel
#                                                                             Total GHG      kg CO2-eq/gal biofuel
#               Separations 2           Separations 2   1      Biorefinery v1 Fossil GHG     kg CO2-eq/gal biofuel
#                                                                             Jobs        person-hours/gal biofuel
#                                                                             Total GHG      kg CO2-eq/gal biofuel

# %% [markdown]
# ### Compute costs and metrics for investments.

# %% [markdown]
# Now evaluate the investments.

# %%
investment_results = my_investments.evaluate_investments(my_designs, sample_count=50)

# %% [markdown]
# The investment amounts are simple how much each tranche costs.

# %%
investment_results.amounts
# Out:
#                  Amount
# Investment
# High R&D      8500000.0
# Low R&D       2050000.0
# Moderate R&D  5900000.0
# No R&D              0.0

# %% [markdown]
# The investment metrics show the values of each metric for each member of the ensemble of simulations.

# %%
investment_results.metrics
# Out:
#                                                                                                Value  \
# Investment Category    Tranche              Scenario      Sample Technology     Index
# No R&D     Conversion  Conversion Reference Bioreference  1      Biorefinery v1 Fossil GHG  3.322701
#                                                                                 Jobs        0.002067
#                                                                                 Total GHG   5.696058
#                                                           2      Biorefinery v1 Fossil GHG  3.322701
#                                                                                 Jobs        0.002067
# ...                                                                                              ...
# High R&D   Separations Separations 2        Separations 2 49     Biorefinery v1 Jobs        0.002053
#                                                                                 Total GHG   4.262284
#                                                           50     Biorefinery v1 Fossil GHG  2.330163
#                                                                                 Jobs        0.001919
#                                                                                 Total GHG   3.982996
#
#                                                                                                                Units
# Investment Category    Tranche              Scenario      Sample Technology     Index
# No R&D     Conversion  Conversion Reference Bioreference  1      Biorefinery v1 Fossil GHG     kg CO2-eq/gal biofuel
#                                                                                 Jobs        person-hours/gal biofuel
#                                                                                 Total GHG      kg CO2-eq/gal biofuel
#                                                           2      Biorefinery v1 Fossil GHG     kg CO2-eq/gal biofuel
#                                                                                 Jobs        person-hours/gal biofuel
# ...                                                                                                              ...
# High R&D   Separations Separations 2        Separations 2 49     Biorefinery v1 Jobs        person-hours/gal biofuel
#                                                                                 Total GHG      kg CO2-eq/gal biofuel
#                                                           50     Biorefinery v1 Fossil GHG     kg CO2-eq/gal biofuel
#                                                                                 Jobs        person-hours/gal biofuel
#                                                                                 Total GHG      kg CO2-eq/gal biofuel
#
# [2400 rows x 2 columns]

# %% [markdown]
# A summary of the metrics is available at the investment level rather than at the tranche level.

# %%
investment_results.summary
# Out:
#                                   Value                     Units
# Investment Sample Index
# No R&D     1      Fossil GHG  13.290803     kg CO2-eq/gal biofuel
#                   Jobs         0.008266  person-hours/gal biofuel
#                   Total GHG   22.784233     kg CO2-eq/gal biofuel
#            2      Fossil GHG  13.290803     kg CO2-eq/gal biofuel
#                   Jobs         0.008266  person-hours/gal biofuel
# ...                                 ...                       ...
# High R&D   49     Jobs         0.006375  person-hours/gal biofuel
#                   Total GHG   14.317461     kg CO2-eq/gal biofuel
#            50     Fossil GHG   8.104267     kg CO2-eq/gal biofuel
#                   Jobs         0.006201  person-hours/gal biofuel
#                   Total GHG   13.805294     kg CO2-eq/gal biofuel
#
# [600 rows x 2 columns]
